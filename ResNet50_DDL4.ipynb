# %% [markdown]
# <a href="https://colab.research.google.com/github/NamLam-L/Transfer-Learning-model/blob/main/ResNet50_DDL4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import keras
keras.__version__
# Out:
# '2.7.0'

# %%
path = "//content//gdrive//MyDrive//ML"
import os
os.path.isdir(path)
# Out:
# True

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np

# %%
model = ResNet50(weights = 'imagenet')
# Out:
# ...
# 102981632/102967424 [==============================] - 1s 0us/step

# %%
base_path = path + "//AnimalTest"
os.path.isdir(base_path)
allfiles = os.listdir(base_path)
allfiles
# Out:
# ['pexels-david-dibert-1300960.jpg',
#  'pexels-gary-whyte-730536.jpg',
#  'pexels-dani-muchow-2955703.jpg',
#  'pexels-anastasia-lashkevich-10306218.jpg',
#  'pexels-rachel-claire-4577141.jpg',
#  'pexels-rachel-claire-4577811.jpg',
#  'Website_SpeciesPage_ForestElephant01_Hero.jpg',
#  'images.jpg',
#  'images (1).jpg',
#  'images (2).jpg',
#  'images (3).jpg',
#  'images (4).jpg',
#  'download.jpg',
#  'roger-the-kangaroo-sanctuary-alice-springs-2_custom-e0dfceba6d2665cc8cc0daa5a57eae2bcda46ad8-s1100-c50.jpg',
#  'images (5).jpg',
#  'images (6).jpg',
#  'images (7).jpg',
#  'images (8).jpg',
#  'download (1).jpg',
#  'download (2).jpg',
#  'download (3).jpg',
#  'images (9).jpg',
#  '261145620_795918767938957_7123019512146976472_n.jpg']

# %%
import matplotlib.pyplot as plt
for filename in allfiles:
  img_path = base_path + "//" + filename
  img = image.load_img(img_path, target_size = (224,224))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis= 0)
  x = preprocess_input(x)


  preds = model.predict(x)
  plt.imshow(img)
  plt.show()
  display(decode_predictions(preds, top = 3))
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# [[('n02129165', 'lion', 0.95185286),
#   ('n02130308', 'cheetah', 0.040017977),
#   ('n02127052', 'lynx', 0.0030874477)]]
# [[('n02129165', 'lion', 0.9107958),
#   ('n02486410', 'baboon', 0.045715846),
#   ('n02487347', 'macaque', 0.008511462)]]
# [[('n02129165', 'lion', 0.6790236),
#   ('n02363005', 'beaver', 0.08758793),
#   ('n02115913', 'dhole', 0.034133084)]]
# [[('n07802026', 'hay', 0.22828233),
#   ('n03770439', 'miniskirt', 0.09633403),
#   ('n02963159', 'cardigan', 0.08045203)]]
# [[('n01871265', 'tusker', 0.38084114),
#   ('n02504458', 'African_elephant', 0.3502893),
#   ('n02504013', 'Indian_elephant', 0.23518477)]]
# [[('n02504013', 'Indian_elephant', 0.4025866),
#   ('n01871265', 'tusker', 0.3023579),
#   ('n02504458', 'African_elephant', 0.29446226)]]
# [[('n01871265', 'tusker', 0.23601146),
#   ('n02504458', 'African_elephant', 0.23146644),
#   ('n02398521', 'hippopotamus', 0.15901722)]]
# ...
